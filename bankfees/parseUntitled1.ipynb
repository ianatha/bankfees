# %%
import openparse

# %%
basic_doc_path = "./data/alpha/deltio-telon-alpha-misthodosia.pdf"
parser = openparse.DocumentParser()
parsed_basic_doc = parser.parse(basic_doc_path)

# %%
fnode = parsed_basic_doc.nodes[0]

# %%
from IPython.display import Image
from base64 import b64decode

# %%
for node in parsed_basic_doc.nodes:
	print()
	print()
	print()
	print("node")
	for element in node.elements:
		if isinstance(element, openparse.schemas.ImageElement):
			print("image")
		else:
			print("element", element.text)
			# print("image element", element.image)
			# Image(b64decode(element.image))
# Out:
# image
# element **Δελτίο Πληροφόρησης περί τελών**
# element **Όνομα του παρόχου λογαριασμού πληρωμών: Alpha Bank**
# element **Όνομα του λογαριασμού: Alpha Μισθοδοσία, Alpha Ταμιευτήριο Μετ’ Αποδοχών**
# element **Ημερομηνία τελευταίας επικαιροποίησης: 17/2/2025**
# element • Το παρόν έγγραφο σας ενημερώνει σχετικά με τα τέλη χρήσης των κύριων υπηρεσιών που
# element συνδέονται με τον λογαριασμό πληρωμών. Σας βοηθάει να συγκρίνετε αυτά τα τέλη με εκείνα άλλων
# λογαριασμών πληρωμών.
# element • Μπορεί να ισχύουν επίσης, τέλη για τη χρήση υπηρεσιών που συνδέονται με τον λογαριασμό τα
# οποία δεν αναφέρονται στο παρόν έγγραφο. Διατίθενται πλήρεις πληροφορίες στα έντυπα «Όροι
# Συναλλαγών: Προμήθειες και Λοιπά Έξοδα» και στο Παράρτημα «Πληρωμές προς Εταιρίες /
# Οργανισμούς».
# element • Διατίθεται δωρεάν γλωσσάριο των όρων που χρησιμοποιούνται στο παρόν έγγραφο.
# element **Υπηρεσία**
# element **Τέλος**
# element **Γενικές υπηρεσίες λογαριασμού**
# element €1,5/αποστολή
# ...
